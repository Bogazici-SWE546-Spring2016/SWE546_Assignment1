# %% [markdown]
# ## Assignment:
#
# Deadline : 09.03.2016 Wed  18:59
#
# * Fit a polynomial of degree $K$ to all columns of the following dataset
# to predict number of vehicles in the years of $2016$,$2017$,$2018$,$2019$ and $2020$.
#
# $$
# y_i = \sum_{k=0}^K w_k x_{i}^k + \epsilon_i
# $$
#
#
# * Fit an AR model to each data sequence
# $$
# y_i = w_1 y_{i-1} + \epsilon_i
# $$
#
# Which model would you prefer? Polynomial or AR?
#
# For each model, plot the data and your model fit $f = A w^*$
#
# ### Bonus:
# Use cross validation for finding the best polynomial order and describe you approach.

# %% [markdown]
# Your Name : Zeyneb ESENDİR

# %%
# %matplotlib inline

import scipy as sc
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pylab as plt
import sys

df_arac = pd.read_csv(u'data/arac.csv',sep=';')

BaseYear = 1966
degree=2

def AR_Model_Fitting(data,TargetYear, str):
    #Set AR Model for given data
    yNew = np.matrix(data[1:]).T
    ANew = np.matrix(data[:-1]).T

    w_ls, E, rank, sigma = np.linalg.lstsq(ANew,yNew)

    fNew = np.matrix([2016, 2017, 2018, 2019, 2020]).T
    fNew[0] = yNew[-1] * w_ls;
    N=len(fNew)
    
    for i in range(N - 1):
        fNew[i+1] = fNew[i] * w_ls
            
    years = np.matrix(df_arac.Year[0:]).T
    yCount=len(yNew)
    c=len(years)
    
    if(c!=yCount):
        years=years[0:yCount]
        
    plt.plot(TargetYear.T, fNew / 1000, 'ro-')
    plt.plot(years, yNew / 1000, 'o-')
    plt.show()
    
    print("\nAR Model for "+ str)
    print(fNew / 1000)

# %%
#CARS

x = np.matrix(df_arac.Year[0:]).T-BaseYear
y = np.matrix(df_arac.Car[0:]).T/1000
vehicle="Cars"

plt.plot(x+BaseYear, y, 'o-')
plt.xlabel('Year')
plt.ylabel('Number of '+ vehicle)

plt.show()

# %%
# Setup the vandermonde matrix
N = len(x)
A = np.hstack((np.power(x,i) for i in range(degree+1)))

# Solve the least squares problem
w_ls,E,rank,sigma = np.linalg.lstsq(A, y)

# Prediction for specific years
TargetYear = np.matrix([2016,2017, 2018, 2019,2020])
x_predict = np.matrix(TargetYear - BaseYear).T
A2 = np.hstack((np.power(x_predict,i) for i in range(degree+1)))
f = A2*w_ls

#just to show complete red line
x_Plot = np.matrix(np.linspace(0,54)).T
Aplot = np.hstack((np.power(x_Plot,i) for i in range(degree+1)))
fplot = Aplot*w_ls

#Plot
plt.plot(x+BaseYear, y, 'o-')
plt.plot(x_Plot+BaseYear, fplot, 'r-')
plt.xlabel('Years')
plt.ylabel('Number of '+ vehicle)
plt.show()

#Display predicted numbers
print("Expected amount of "+vehicle+ " in:")
print('\n',"2016: ",f[1],'\n',"2017: ",f[2],'\n',"2018: ",f[3] ,'\n',"2019: ",f[4],'\n',"2020: ",f[4] )

#AR Model:
AR_Model_Fitting(df_arac.Car,TargetYear,vehicle)
# Out:
# Expected amount of Cars in:
#
#  2016:  [[ 10879.24340139]]
#  2017:  [[ 11364.44100742]]
#  2018:  [[ 11860.40433973]]
#  2019:  [[ 12367.1333983]]
#  2020:  [[ 12367.1333983]]
# AR Model for Cars
# [[ 11203.217]
#  [ 11943.   ]
#  [ 12731.633]
#  [ 13572.342]
#  [ 14468.565]]

# %%
#MINIBUS


x = np.matrix(df_arac.Year[0:]).T-BaseYear
y = np.matrix(df_arac.Minibus[0:]).T/1000
vehicle="Minibuses"

plt.plot(x+BaseYear, y, 'o-')
plt.xlabel('Year')
plt.ylabel('Number of '+ vehicle)

plt.show()

# %%
# Setup the vandermonde matrix
N = len(x)
A = np.hstack((np.power(x,i) for i in range(degree+1)))

# Solve the least squares problem
w_ls,E,rank,sigma = np.linalg.lstsq(A, y)

# Prediction for specific years
TargetYear = np.matrix([2016,2017, 2018, 2019,2020])
x_predict = np.matrix(TargetYear - BaseYear).T
A2 = np.hstack((np.power(x_predict,i) for i in range(degree+1)))
f = A2*w_ls

#just to show complete red line
x_Plot = np.matrix(np.linspace(0,54)).T
Aplot = np.hstack((np.power(x_Plot,i) for i in range(degree+1)))
fplot = Aplot*w_ls

#Plot
plt.plot(x+BaseYear, y, 'o-')
plt.plot(x_Plot+BaseYear, fplot, 'r-')
plt.xlabel('Years')
plt.ylabel('Number of '+ vehicle)
plt.show()

#Display predicted numbers
print("Expected amount of "+vehicle+ " in:")
print('\n',"2016: ",f[1],'\n',"2017: ",f[2],'\n',"2018: ",f[3] ,'\n',"2019: ",f[4],'\n',"2020: ",f[4] )

#AR Model:
AR_Model_Fitting(df_arac.Minibus,TargetYear,vehicle)
# Out:
# Expected amount of Minibuses in:
#
#  2016:  [[ 502.09693095]]
#  2017:  [[ 520.70296022]]
#  2018:  [[ 539.65842822]]
#  2019:  [[ 558.96333495]]
#  2020:  [[ 558.96333495]]
# AR Model for Minibuses
# [[ 465.835]
#  [ 485.657]
#  [ 506.323]
#  [ 527.868]
#  [ 550.33 ]]

# %%
#BUS

x = np.matrix(df_arac.Year[0:]).T-BaseYear
y = np.matrix(df_arac.Bus[0:]).T/1000
vehicle="Buses"

plt.plot(x+BaseYear, y, 'o-')
plt.xlabel('Year')
plt.ylabel('Number of '+ vehicle)

plt.show()

# %%
# Setup the vandermonde matrix
N = len(x)
A = np.hstack((np.power(x,i) for i in range(degree+1)))

# Solve the least squares problem
w_ls,E,rank,sigma = np.linalg.lstsq(A, y)

# Prediction for specific years
TargetYear = np.matrix([2016,2017, 2018, 2019,2020])
x_predict = np.matrix(TargetYear - BaseYear).T
A2 = np.hstack((np.power(x_predict,i) for i in range(degree+1)))
f = A2*w_ls

#just to show complete red line
x_Plot = np.matrix(np.linspace(0,54)).T
Aplot = np.hstack((np.power(x_Plot,i) for i in range(degree+1)))
fplot = Aplot*w_ls

#Plot
plt.plot(x+BaseYear, y, 'o-')
plt.plot(x_Plot+BaseYear, fplot, 'r-')
plt.xlabel('Years')
plt.ylabel('Number of '+ vehicle)
plt.show()

#Display predicted numbers
print("Expected amount of "+vehicle+ " in:")
print('\n',"2016: ",f[1],'\n',"2017: ",f[2],'\n',"2018: ",f[3] ,'\n',"2019: ",f[4],'\n',"2020: ",f[4] )

#AR Model:
AR_Model_Fitting(df_arac.Bus,TargetYear,vehicle)
# Out:
# Expected amount of Buses in:
#
#  2016:  [[ 262.78222077]]
#  2017:  [[ 272.85249677]]
#  2018:  [[ 283.12346462]]
#  2019:  [[ 293.59512432]]
#  2020:  [[ 293.59512432]]
# AR Model for Buses
# [[ 224.461]
#  [ 232.644]
#  [ 241.125]
#  [ 249.915]
#  [ 259.026]]

# %%
#SMALLTRUCKS

x = np.matrix(df_arac.Year[0:]).T-BaseYear
y = np.matrix(df_arac.SmallTruck[0:]).T/1000
vehicle="SmallTrucks"

plt.plot(x+BaseYear, y, 'o-')
plt.xlabel('Year')
plt.ylabel('Number of '+ vehicle)

plt.show()

# %%
# Setup the vandermonde matrix
N = len(x)
A = np.hstack((np.power(x,i) for i in range(degree+1)))

# Solve the least squares problem
w_ls,E,rank,sigma = np.linalg.lstsq(A, y)

# Prediction for specific years
TargetYear = np.matrix([2016,2017, 2018, 2019,2020])
x_predict = np.matrix(TargetYear - BaseYear).T
A2 = np.hstack((np.power(x_predict,i) for i in range(degree+1)))
f = A2*w_ls

#just to show complete red line
x_Plot = np.matrix(np.linspace(0,54)).T
Aplot = np.hstack((np.power(x_Plot,i) for i in range(degree+1)))
fplot = Aplot*w_ls

#Plot
plt.plot(x+BaseYear, y, 'o-')
plt.plot(x_Plot+BaseYear, fplot, 'r-')
plt.xlabel('Years')
plt.ylabel('Number of '+ vehicle)
plt.show()

#Display predicted numbers
print("Expected amount of "+vehicle+ " in:")
print('\n',"2016: ",f[1],'\n',"2017: ",f[2],'\n',"2018: ",f[3] ,'\n',"2019: ",f[4],'\n',"2020: ",f[4] )

#AR Model:
AR_Model_Fitting(df_arac.SmallTruck,TargetYear,vehicle)
# Out:
# Expected amount of SmallTrucks in:
#
#  2016:  [[ 3443.93107071]]
#  2017:  [[ 3630.40008798]]
#  2018:  [[ 3821.7121366]]
#  2019:  [[ 4017.86721656]]
#  2020:  [[ 4017.86721656]]
# AR Model for SmallTrucks
# [[ 3489.94 ]
#  [ 3764.617]
#  [ 4060.913]
#  [ 4380.529]
#  [ 4725.3  ]]

# %%
#TRUCKS

x = np.matrix(df_arac.Year[0:]).T-BaseYear
y = np.matrix(df_arac.Truck[0:]).T/1000
vehicle="Trucks"

plt.plot(x+BaseYear, y, 'o-')
plt.xlabel('Year')
plt.ylabel('Number of '+ vehicle)

plt.show()

# %%
# Setup the vandermonde matrix
N = len(x)
A = np.hstack((np.power(x,i) for i in range(degree+1)))

# Solve the least squares problem
w_ls,E,rank,sigma = np.linalg.lstsq(A, y)

# Prediction for specific years
TargetYear = np.matrix([2016,2017, 2018, 2019,2020])
x_predict = np.matrix(TargetYear - BaseYear).T
A2 = np.hstack((np.power(x_predict,i) for i in range(degree+1)))
f = A2*w_ls

#just to show complete red line
x_Plot = np.matrix(np.linspace(0,54)).T
Aplot = np.hstack((np.power(x_Plot,i) for i in range(degree+1)))
fplot = Aplot*w_ls

#Plot
plt.plot(x+BaseYear, y, 'o-')
plt.plot(x_Plot+BaseYear, fplot, 'r-')
plt.xlabel('Years')
plt.ylabel('Number of '+ vehicle)
plt.show()

#Display predicted numbers
print("Expected amount of "+vehicle+ " in:")
print('\n',"2016: ",f[1],'\n',"2017: ",f[2],'\n',"2018: ",f[3] ,'\n',"2019: ",f[4],'\n',"2020: ",f[4] )

AR_Model_Fitting(df_arac.Truck,TargetYear,vehicle)
# Out:
# Expected amount of Trucks in:
#
#  2016:  [[ 918.70462385]]
#  2017:  [[ 951.86042548]]
#  2018:  [[ 985.65249049]]
#  2019:  [[ 1020.08081891]]
#  2020:  [[ 1020.08081891]]
# AR Model for Trucks
# [[ 831.361]
#  [ 861.136]
#  [ 891.978]
#  [ 923.924]
#  [ 957.014]]

# %%
#MotorCycle

x = np.matrix(df_arac.Year[0:]).T-BaseYear
y = np.matrix(df_arac.Motorcycle[0:]).T/1000
vehicle="Motorcycles"

plt.plot(x+BaseYear, y, 'o-')
plt.xlabel('Year')
plt.ylabel('Number of '+ vehicle)

plt.show()

# %%
# Setup the vandermonde matrix
N = len(x)
A = np.hstack((np.power(x,i) for i in range(degree+1)))

# Solve the least squares problem
w_ls,E,rank,sigma = np.linalg.lstsq(A, y)

# Prediction for specific years
TargetYear = np.matrix([2016,2017, 2018, 2019,2020])
x_predict = np.matrix(TargetYear - BaseYear).T
A2 = np.hstack((np.power(x_predict,i) for i in range(degree+1)))
f = A2*w_ls

#just to show complete red line
x_Plot = np.matrix(np.linspace(0,54)).T
Aplot = np.hstack((np.power(x_Plot,i) for i in range(degree+1)))
fplot = Aplot*w_ls

#Plot
plt.plot(x+BaseYear, y, 'o-')
plt.plot(x_Plot+BaseYear, fplot, 'r-')
plt.xlabel('Years')
plt.ylabel('Number of '+ vehicle)
plt.show()

#Display predicted numbers
print("Expected amount of "+vehicle+ " in:")
print('\n',"2016: ",f[1],'\n',"2017: ",f[2],'\n',"2018: ",f[3] ,'\n',"2019: ",f[4],'\n',"2020: ",f[4] )

AR_Model_Fitting(df_arac.Motorcycle,TargetYear,vehicle)
# Out:
# Expected amount of Motorcycles in:
#
#  2016:  [[ 3218.51026603]]
#  2017:  [[ 3370.10876054]]
#  2018:  [[ 3525.24384109]]
#  2019:  [[ 3683.91550768]]
#  2020:  [[ 3683.91550768]]
# AR Model for Motorcycles
# [[ 3118.72 ]
#  [ 3309.631]
#  [ 3512.229]
#  [ 3727.229]
#  [ 3955.39 ]]

# %%
#SpecialVehicles

x = np.matrix(df_arac.Year[0:]).T-BaseYear
y = np.matrix(df_arac.SpecialVehicles[0:]).T/1000
vehicle="SpecialVehicles"

plt.plot(x+BaseYear, y, 'o-')
plt.xlabel('Year')
plt.ylabel('Number of '+ vehicle)

plt.show()

# %%
# Setup the vandermonde matrix
N = len(x)
A = np.hstack((np.power(x,i) for i in range(degree+1)))

# Solve the least squares problem
w_ls,E,rank,sigma = np.linalg.lstsq(A, y)

# Prediction for specific years
TargetYear = np.matrix([2016,2017, 2018, 2019,2020])
x_predict = np.matrix(TargetYear - BaseYear).T
A2 = np.hstack((np.power(x_predict,i) for i in range(degree+1)))
f = A2*w_ls

#just to show complete red line
x_Plot = np.matrix(np.linspace(0,54)).T
Aplot = np.hstack((np.power(x_Plot,i) for i in range(degree+1)))
fplot = Aplot*w_ls

#Plot
plt.plot(x+BaseYear, y, 'o-')
plt.plot(x_Plot+BaseYear, fplot, 'r-')
plt.xlabel('Years')
plt.ylabel('Number of '+ vehicle)
plt.show()

#Display predicted numbers
print("Expected amount of "+vehicle+ " in:")
print('\n',"2016: ",f[1],'\n',"2017: ",f[2],'\n',"2018: ",f[3] ,'\n',"2019: ",f[4],'\n',"2020: ",f[4] )
AR_Model_Fitting(df_arac.SpecialVehicles,TargetYear,vehicle)
# Out:
# Expected amount of SpecialVehicles in:
#
#  2016:  [[ 41.59942611]]
#  2017:  [[ 41.45863256]]
#  2018:  [[ 41.27695262]]
#  2019:  [[ 41.05438629]]
#  2020:  [[ 41.05438629]]
# AR Model for SpecialVehicles
# [[ 45.494]
#  [ 45.853]
#  [ 46.215]
#  [ 46.58 ]
#  [ 46.948]]

# %%
#Machinery

x = np.matrix(df_arac.Year[0:38]).T-BaseYear
y = np.matrix(df_arac.Machinery[0:38]).T/1000
vehicle="Machinery"

plt.plot(x+BaseYear, y, 'o-')
plt.xlabel('Year')
plt.ylabel('Number of '+ vehicle)

plt.show()

# %%
# Setup the vandermonde matrix
N = len(x)
A = np.hstack((np.power(x,i) for i in range(degree+1)))

# Solve the least squares problem
w_ls,E,rank,sigma = np.linalg.lstsq(A, y)

# Prediction for specific years
TargetYear = np.matrix([2016,2017, 2018, 2019,2020])
x_predict = np.matrix(TargetYear - BaseYear).T
A2 = np.hstack((np.power(x_predict,i) for i in range(degree+1)))
f = A2*w_ls

#just to show complete red line
x_Plot = np.matrix(np.linspace(0,54)).T
Aplot = np.hstack((np.power(x_Plot,i) for i in range(degree+1)))
fplot = Aplot*w_ls

#Plot
plt.plot(x+BaseYear, y, 'o-')
plt.plot(x_Plot+BaseYear, fplot, 'r-')
plt.xlabel('Years')
plt.ylabel('Number of '+ vehicle)
plt.show()

#Display predicted numbers
print("Expected amount of "+vehicle+ " in:")
print('\n',"2016: ",f[1],'\n',"2017: ",f[2],'\n',"2018: ",f[3] ,'\n',"2019: ",f[4],'\n',"2020: ",f[4] )

AR_Model_Fitting(df_arac.Machinery[0:38],TargetYear,vehicle)
# Out:
# Expected amount of Machinery in:
#
#  2016:  [[ 265.47630299]]
#  2017:  [[ 275.54072256]]
#  2018:  [[ 285.7935058]]
#  2019:  [[ 296.2346527]]
#  2020:  [[ 296.2346527]]
# AR Model for Machinery
# [[ 145.967]
#  [ 154.469]
#  [ 163.466]
#  [ 172.987]
#  [ 183.063]]

# %%
#Tractor

x = np.matrix(df_arac.Year[15:]).T-BaseYear
y = np.matrix(df_arac.Tractor[15:]).T/1000
vehicle="Tractor"

plt.plot(x+BaseYear, y, 'o-')
plt.xlabel('Year')
plt.ylabel('Number of '+ vehicle)

plt.show()

# %%
# Setup the vandermonde matrix
N = len(x)
A = np.hstack((np.power(x,i) for i in range(degree+1)))   
    
# Solve the least squares problem
w_ls,E,rank,sigma = np.linalg.lstsq(A, y)


# Prediction for specific years
TargetYear = np.matrix([2016,2017, 2018, 2019,2020])
x_predict = np.matrix(TargetYear - BaseYear).T
A2 = np.hstack((np.power(x_predict,i) for i in range(degree+1)))
f = A2*w_ls

#just to show complete red line
x_Plot = np.matrix(np.linspace(0,54)).T
Aplot = np.hstack((np.power(x_Plot,i) for i in range(degree+1)))
fplot = Aplot*w_ls

#Plot
plt.plot(x+BaseYear, y, 'o-')
plt.plot(x_Plot+BaseYear, fplot, 'r-')
plt.xlabel('Years')
plt.ylabel('Number of '+ vehicle)
plt.show()

#Display predicted numbers
print("Expected amount of "+vehicle+ " in:")
print('\n',"2016: ",f[1],'\n',"2017: ",f[2],'\n',"2018: ",f[3] ,'\n',"2019: ",f[4],'\n',"2020: ",f[4] )

AR_Model_Fitting(df_arac.Tractor[15:],TargetYear,vehicle)
# Out:
# Expected amount of Tractor in:
#
#  2016:  [[ 1662.3284409]]
#  2017:  [[ 1690.30840391]]
#  2018:  [[ 1717.85670752]]
#  2019:  [[ 1744.97335173]]
#  2020:  [[ 1744.97335173]]
# AR Model for Tractor
# [[ 1744.959]
#  [ 1804.326]
#  [ 1865.713]
#  [ 1929.189]
#  [ 1994.824]]
