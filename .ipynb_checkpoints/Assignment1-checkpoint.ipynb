# %% [markdown]
# Assignment:
#
# Fit a polynomial of degree K to all columns of the following dataset
# to predict number of vehicles in the years of 2016 2017 2018 2019 and 2020.
#
# Bonus:
#
# Use cross validation for finding the best polynomial order and describe you approach.
#
# Deadline : 09.03.2016 Wed  18:59

# %% [markdown]
# Your Name : Mahmut Ali ÖZKURAN

# %%
# %matplotlib inline

import scipy as sc
import scipy.stats as scst
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pylab as plt

df_arac = pd.read_csv(u'data/arac.csv',sep=';')
df_arac
# Out:
#     Year       All       Car  Minibus     Bus  SmallTruck   Truck  Motorcycle  \
# 0   1966    231977     91469    10913   12041       31462   47931       32099
# 1   1967    284194    112367    16008   13332       39927   56889       39647
# 2   1968    318768    125375    18967   13948       43441   62616       47062
# 3   1969    354398    137345    20540   15529       48655   69478       52959
# 4   1970    369808    137771    20916   15980       52152   70730       60994
# 5   1971    403880    153676    22380   17140       57011   73433       68417
# 6   1972    460087    187272    25559   18504       62796   78920       74402
# 7   1973    543318    240360    30055   20011       71043   86780       80860
# 8   1974    647947    313160    34122   21404       81025   95309       86028
# 9   1975    785920    403546    40623   23763       98579  108381       91421
# 10  1976    920141    488894    46066   25388      116861  122176       96984
# ...

# %%
BaseYear = 1966

x1 = np.matrix(df_arac.Year[0:]).T-BaseYear

y_all = np.matrix(df_arac.All[0:]).T/1000000.0
y_car = np.matrix(df_arac.Car[0:]).T/1000000.0
y_minibus = np.matrix(df_arac.Minibus[0:]).T/1000000.0
y_bus = np.matrix(df_arac.Bus[0:]).T/1000000.0
y_smallTruck = np.matrix(df_arac.SmallTruck[0:]).T/1000000.0
y_truck = np.matrix(df_arac.Truck[0:]).T/1000000.0
y_motorcycle = np.matrix(df_arac.Motorcycle[0:]).T/1000000.0
y_specialVehicles = np.matrix(df_arac.SpecialVehicles[0:]).T/1000000.0
y_machinery = np.matrix(df_arac.Machinery[0:]).T/1000000.0
y_tractor = np.matrix(df_arac.Tractor[0:]).T/1000000.0
#y = np.matrix(df_arac.Minibus[0:-1:5]).T/1000000.0

plt.plot(x1+BaseYear, y_car, 'o-')
plt.xlabel('Year')
plt.ylabel('Number of Cars (Millions)')

plt.show()

# %%
#TargetYear = np.arange(1966,2016,1)
t = np.arange(0,50,1)
BaseYear = 1966

def square(list):
    return [i ** 2 for i in list]

def fitit(a,b):
    coeffs = np.polyfit(t,a,deg=b)
    t_x=np.squeeze(np.asarray(coeffs.T))
    pf = np.polyval(np.poly1d(t_x), t)
    plt.plot(x1+BaseYear, a , 'o-')
    plt.plot(x1+BaseYear, pf , 'r')
    plt.xlabel('Year')
    plt.ylabel('Number of Cars (Millions)')
    plt.show()
    print('2016 : %s' % np.polyval(np.poly1d(t_x), 50))
    print('2017 : %s' % np.polyval(np.poly1d(t_x), 51))
    print('2018 : %s' % np.polyval(np.poly1d(t_x), 52))
    print('2019 : %s' % np.polyval(np.poly1d(t_x), 53))
    print('2020 : %s' % np.polyval(np.poly1d(t_x), 54))
    a = np.squeeze(np.asarray(a))
    print('Maximum Absolute Error %.1f' % max(a-pf))
    print('Total Square Diffrence %.1f' % sum(square(a - pf)))

def fititx(a):
    print('K = 1')
    fitit(a,1)    
    print('K = 2')
    fitit(a,2)    
    print('K = 3')
    fitit(a,3)    
    print('K = 4')
    fitit(a,4)    
    print('K = 5')
    fitit(a,5)    
    print('K = 6')
    fitit(a,6)    
    print('K = 7')
    fitit(a,7)    
    print('K = 8')
    fitit(a,8)    
    print('K = 9')
    fitit(a,9)    
    print('K = 10')
    fitit(a,10)    

print('---------------------------------------------')
print('All Vehicles')
print('---------------------------------------------')
fititx(y_all)
print('---------------------------------------------')
print('Cars')
print('---------------------------------------------')
fititx(y_car)
print('---------------------------------------------')
print('Minibus')
print('---------------------------------------------')
fititx(y_minibus)
print('---------------------------------------------')
print('Bus')
print('---------------------------------------------')
fititx(y_bus)
print('---------------------------------------------')
print('Small Truck')
print('---------------------------------------------')
fititx(y_smallTruck)
print('---------------------------------------------')
print('Truck')
print('---------------------------------------------')
fititx(y_truck)
print('---------------------------------------------')
print('Motorcycle')
print('---------------------------------------------')
fititx(y_motorcycle)
print('---------------------------------------------')
print('Special Vehicles')
print('---------------------------------------------')
fititx(y_specialVehicles)
print('---------------------------------------------')
print('Machinery')
print('---------------------------------------------')
fititx(y_machinery)
print('---------------------------------------------')
print('Tractor')
print('---------------------------------------------')
fititx(y_tractor)
# Out:
# ---------------------------------------------
# All Vehicles
# ---------------------------------------------
# K = 1
# 2016 : 15.6638110694
# 2017 : 16.0391138329
# 2018 : 16.4144165964
# 2019 : 16.7897193599
# 2020 : 17.1650221234
# Maximum Absolute Error 4.6
# Total Square Diffrence 180.4
# K = 2
# 2016 : 20.086346001
# 2017 : 20.9819469918
# 2018 : 21.8975594528
# 2019 : 22.8331833841
# 2020 : 23.7888187857
# Maximum Absolute Error 0.7
# Total Square Diffrence 7.0
# K = 3
# 2016 : 20.9641148708
# 2017 : 22.0662497132
# 2018 : 23.2082550502
# 2019 : 24.3908802788
# 2020 : 25.6148747961
# Maximum Absolute Error 0.4
# Total Square Diffrence 2.6
# K = 4
# 2016 : 21.1171928181
# 2017 : 22.2793582281
# 2018 : 23.4917840385
# 2019 : 24.756134481
# 2020 : 26.0741076698
# Maximum Absolute Error 0.4
# Total Square Diffrence 2.5
# K = 5
# 2016 : 21.0464779026
# 2017 : 22.1670463036
# 2018 : 23.3266759102
# 2019 : 24.5253405096
# 2020 : 25.7629069013
# Maximum Absolute Error 0.3
# ...
